# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')
# Out:
# C:\Users\rchoudhary\AppData\Local\Temp\ipykernel_4012\2819415339.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %%
from tensorflow import keras
from keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 6s 16ms/step - loss: 0.4807 - binary_accuracy: 0.7724 - val_loss: 0.4350 - val_binary_accuracy: 0.8011
# Epoch 2/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.4234 - binary_accuracy: 0.8016 - val_loss: 0.4050 - val_binary_accuracy: 0.8096
# Epoch 3/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.4089 - binary_accuracy: 0.8085 - val_loss: 0.3964 - val_binary_accuracy: 0.8130
# Epoch 4/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4016 - binary_accuracy: 0.8126 - val_loss: 0.3934 - val_binary_accuracy: 0.8192
# Epoch 5/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3967 - binary_accuracy: 0.8145 - val_loss: 0.3874 - val_binary_accuracy: 0.8226
# Epoch 6/200
# 175/175 [==============================] - 4s 24ms/step - loss: 0.3916 - binary_accuracy: 0.8180 - val_loss: 0.3848 - val_binary_accuracy: 0.8239
# Epoch 7/200
# 175/175 [==============================] - 4s 25ms/step - loss: 0.3890 - binary_accuracy: 0.8185 - val_loss: 0.3797 - val_binary_accuracy: 0.8229
# Epoch 8/200
# 175/175 [==============================] - 4s 25ms/step - loss: 0.3852 - binary_accuracy: 0.8211 - val_loss: 0.3783 - val_binary_accuracy: 0.8255
# Epoch 9/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3820 - binary_accuracy: 0.8226 - val_loss: 0.3750 - val_binary_accuracy: 0.8286
# Epoch 10/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3794 - binary_accuracy: 0.8231 - val_loss: 0.3726 - val_binary_accuracy: 0.8299
# Epoch 11/200
# 175/175 [==============================] - 4s 23ms/step - loss: 0.3766 - binary_accuracy: 0.8268 - val_loss: 0.3764 - val_binary_accuracy: 0.8278
# Epoch 12/200
# 175/175 [==============================] - 5s 28ms/step - loss: 0.3745 - binary_accuracy: 0.8274 - val_loss: 0.3686 - val_binary_accuracy: 0.8322
# Epoch 13/200
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3704 - binary_accuracy: 0.8290 - val_loss: 0.3709 - val_binary_accuracy: 0.8311
# Epoch 14/200
# 175/175 [==============================] - 4s 24ms/step - loss: 0.3698 - binary_accuracy: 0.8285 - val_loss: 0.3670 - val_binary_accuracy: 0.8319
# Epoch 15/200
# 175/175 [==============================] - 5s 26ms/step - loss: 0.3682 - binary_accuracy: 0.8295 - val_loss: 0.3674 - val_binary_accuracy: 0.8332
# Epoch 16/200
# 175/175 [==============================] - 4s 26ms/step - loss: 0.3668 - binary_accuracy: 0.8308 - val_loss: 0.3648 - val_binary_accuracy: 0.8331
# Epoch 17/200
# 175/175 [==============================] - 4s 20ms/step - loss: 0.3639 - binary_accuracy: 0.8318 - val_loss: 0.3640 - val_binary_accuracy: 0.8311
# Epoch 18/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3620 - binary_accuracy: 0.8321 - val_loss: 0.3638 - val_binary_accuracy: 0.8325
# Epoch 19/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3609 - binary_accuracy: 0.8336 - val_loss: 0.3661 - val_binary_accuracy: 0.8327
# Epoch 20/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3594 - binary_accuracy: 0.8340 - val_loss: 0.3610 - val_binary_accuracy: 0.8347
# Epoch 21/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3587 - binary_accuracy: 0.8332 - val_loss: 0.3603 - val_binary_accuracy: 0.8357
# Epoch 22/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3566 - binary_accuracy: 0.8353 - val_loss: 0.3583 - val_binary_accuracy: 0.8357
# Epoch 23/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3551 - binary_accuracy: 0.8366 - val_loss: 0.3581 - val_binary_accuracy: 0.8352
# Epoch 24/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3541 - binary_accuracy: 0.8366 - val_loss: 0.3588 - val_binary_accuracy: 0.8367
# Epoch 25/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3529 - binary_accuracy: 0.8373 - val_loss: 0.3611 - val_binary_accuracy: 0.8345
# Epoch 26/200
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3504 - binary_accuracy: 0.8375 - val_loss: 0.3568 - val_binary_accuracy: 0.8362
# Epoch 27/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3502 - binary_accuracy: 0.8377 - val_loss: 0.3610 - val_binary_accuracy: 0.8332
# Epoch 28/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3499 - binary_accuracy: 0.8395 - val_loss: 0.3573 - val_binary_accuracy: 0.8355
# Epoch 29/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3489 - binary_accuracy: 0.8381 - val_loss: 0.3556 - val_binary_accuracy: 0.8371
# Epoch 30/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3479 - binary_accuracy: 0.8399 - val_loss: 0.3556 - val_binary_accuracy: 0.8377
# Epoch 31/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3481 - binary_accuracy: 0.8392 - val_loss: 0.3540 - val_binary_accuracy: 0.8382
# Epoch 32/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3438 - binary_accuracy: 0.8416 - val_loss: 0.3561 - val_binary_accuracy: 0.8387
# Epoch 33/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3449 - binary_accuracy: 0.8404 - val_loss: 0.3549 - val_binary_accuracy: 0.8363
# Epoch 34/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3433 - binary_accuracy: 0.8422 - val_loss: 0.3546 - val_binary_accuracy: 0.8379
# Epoch 35/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3429 - binary_accuracy: 0.8420 - val_loss: 0.3529 - val_binary_accuracy: 0.8398
# Epoch 36/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3412 - binary_accuracy: 0.8432 - val_loss: 0.3548 - val_binary_accuracy: 0.8375
# Epoch 37/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3409 - binary_accuracy: 0.8425 - val_loss: 0.3521 - val_binary_accuracy: 0.8396
# Epoch 38/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3393 - binary_accuracy: 0.8430 - val_loss: 0.3517 - val_binary_accuracy: 0.8401
# Epoch 39/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3397 - binary_accuracy: 0.8435 - val_loss: 0.3506 - val_binary_accuracy: 0.8398
# Epoch 40/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3377 - binary_accuracy: 0.8438 - val_loss: 0.3524 - val_binary_accuracy: 0.8397
# Epoch 41/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3370 - binary_accuracy: 0.8443 - val_loss: 0.3512 - val_binary_accuracy: 0.8379
# Epoch 42/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3372 - binary_accuracy: 0.8445 - val_loss: 0.3542 - val_binary_accuracy: 0.8392
# Epoch 43/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3363 - binary_accuracy: 0.8447 - val_loss: 0.3521 - val_binary_accuracy: 0.8400
# Epoch 44/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3343 - binary_accuracy: 0.8451 - val_loss: 0.3529 - val_binary_accuracy: 0.8387
# <Axes: title={'center': 'Accuracy'}>
