# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')
# Out:
# C:\Users\rchoudhary\AppData\Local\Temp\ipykernel_1316\2426236682.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from keras import layers
from keras import callbacks

# %%
spotify = pd.read_csv('spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# %%
# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape),
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0, # suppress output since we'll plot the curves
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 0.1959

# %%
# Start the plot at epoch 10
history_df.loc[10:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1959

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Epoch 1/50
# 49/49 [==============================] - 1s 9ms/step - loss: 0.2166 - val_loss: 0.2026
# Epoch 2/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1991 - val_loss: 0.2013
# Epoch 3/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1946 - val_loss: 0.1995
# Epoch 4/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1912 - val_loss: 0.1998
# Epoch 5/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1903 - val_loss: 0.1992
# Epoch 6/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1887 - val_loss: 0.1971
# Epoch 7/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1870 - val_loss: 0.1984
# Epoch 8/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1866 - val_loss: 0.1973
# Epoch 9/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1857 - val_loss: 0.1974
# Epoch 10/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1845 - val_loss: 0.1970
# Epoch 11/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1836 - val_loss: 0.1969
# Epoch 12/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1831 - val_loss: 0.1981
# Epoch 13/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1820 - val_loss: 0.1965
# Epoch 14/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1817 - val_loss: 0.1969
# Epoch 15/50
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1805 - val_loss: 0.1968
# Epoch 16/50
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1804 - val_loss: 0.1997
# Epoch 17/50
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1804 - val_loss: 0.1985
# Epoch 18/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1797 - val_loss: 0.1999
# Epoch 19/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1788 - val_loss: 0.1991
# Epoch 20/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1782 - val_loss: 0.1973
# Epoch 21/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1770 - val_loss: 0.1989
# Epoch 22/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1771 - val_loss: 0.1985
# Epoch 23/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1766 - val_loss: 0.1986
# Epoch 24/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1764 - val_loss: 0.1986
# Epoch 25/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1760 - val_loss: 0.1982
# Epoch 26/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1755 - val_loss: 0.1993
# Epoch 27/50
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1747 - val_loss: 0.2017
# Epoch 28/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1746 - val_loss: 0.1990
# Epoch 29/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1747 - val_loss: 0.1998
# Epoch 30/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1738 - val_loss: 0.2015
# Epoch 31/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1730 - val_loss: 0.1989
# Epoch 32/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1725 - val_loss: 0.2004
# Epoch 33/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1724 - val_loss: 0.2011
# Epoch 34/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1720 - val_loss: 0.2019
# Epoch 35/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1718 - val_loss: 0.2016
# Epoch 36/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.2019
# Epoch 37/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1717 - val_loss: 0.2005
# Epoch 38/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1720 - val_loss: 0.2021
# Epoch 39/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.2035
# Epoch 40/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1705 - val_loss: 0.2019
# Epoch 41/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1697 - val_loss: 0.2057
# Epoch 42/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1686 - val_loss: 0.2031
# Epoch 43/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1677 - val_loss: 0.2034
# Epoch 44/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1678 - val_loss: 0.2022
# Epoch 45/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1685 - val_loss: 0.2032
# Epoch 46/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1667 - val_loss: 0.2053
# Epoch 47/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1667 - val_loss: 0.2044
# Epoch 48/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1665 - val_loss: 0.2045
# Epoch 49/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1659 - val_loss: 0.2044
# Epoch 50/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1663 - val_loss: 0.2035
# Minimum Validation Loss: 0.1965

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),    
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    callbacks=[early_stopping]
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Epoch 1/50
# 49/49 [==============================] - 1s 7ms/step - loss: 0.3114 - val_loss: 0.2120
# Epoch 2/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.2051 - val_loss: 0.2039
# Epoch 3/50
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1990 - val_loss: 0.2015
# Epoch 4/50
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1961 - val_loss: 0.1994
# Epoch 5/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1935 - val_loss: 0.1987
# Epoch 6/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1919 - val_loss: 0.1989
# Epoch 7/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1906 - val_loss: 0.1990
# Epoch 8/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1893 - val_loss: 0.1974
# Epoch 9/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1883 - val_loss: 0.1972
# Epoch 10/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1876 - val_loss: 0.1977
# Epoch 11/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1869 - val_loss: 0.1978
# Epoch 12/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1863 - val_loss: 0.1994
# Epoch 13/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1862 - val_loss: 0.1984
# Minimum Validation Loss: 0.1972
